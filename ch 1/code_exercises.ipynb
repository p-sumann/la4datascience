# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# The vectors
v = np.array([1,2])
w = np.array([4,-6])
vPlusW = v+w


# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(v[0],v[1],w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(0,0,vPlusW[0],vPlusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v+w'])
plt.title('Vectors , , and ')
# plt.savefig('Figure_02_02a.png',dpi=300) # write out the fig to a file
plt.show()
     

# vector difference
vMinusW = v-w


# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(0,0,w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(w[0],w[1],vMinusW[0],vMinusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v-w'])
plt.title('Vectors  , , and ')
# plt.savefig('Figure_02_02b.png',dpi=300)
plt.show()

# %% [markdown]
# norm of a vector

# %%
def eucledian_norm(x):
    return np.sqrt(np.sum(x**2))

# %%
x = np.array([0,0,1])
eucledian_norm(x)
# Out:
# 1.0

# %%
np.linalg.norm(x,axis=0)
# Out:
# 1.0

# %%
def unit_vector(x):
    return x / np.linalg.norm(x)

# %%
unit_vector(x)
# Out:
# array([0.26726124, 0.53452248, 0.80178373])

# %%
def vector_with_magnitude(x, mag):
    return mag *(x / np.linalg.norm(x))

# %%
sp = vector_with_magnitude(x, 5)
sp
# Out:
# array([1.33630621, 2.67261242, 4.00891863])

# %%
np.linalg.norm(x), np.linalg.norm(sp)
# Out:
# (3.7416573867739413, 5.0)

# %%
# the row vector to transpose
v = np.array([[1,2,3]])

# initialize the column vector
vt = np.zeros((3,1))

# direct implementation of the formula using a for loop
for i in range(v.shape[1]):
  vt[i,0] = v[0,i]

# %%
def tranpose(x: np.array):
    a, b = x.shape
    vt = np.zeros((b,a))
    for i in range(a):
        for j in range(b):
            vt[j][i] = x[i][j]    
    return vt

# %%
a = np.array([[1, 2], [3, 4]])
print(v)
print(tranpose(v))
# Out:
# [[1 2 3]]
# [[1.]
#  [2.]
#  [3.]]

# %%
x
# Out:
# array([1, 2, 3])

# %%
np.linalg.norm(x)
# Out:
# 3.7416573867739413

# %%
np.dot(x,x)
# Out:
# 14

# %%
eucledian_norm(x) ** 2
# Out:
# 14.0

# %%
def commucative(a , b):
    a_b = np.dot(b,a)
    b_a =
